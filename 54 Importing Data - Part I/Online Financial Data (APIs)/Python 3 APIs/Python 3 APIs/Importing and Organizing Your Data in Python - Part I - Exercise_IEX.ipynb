# %% [markdown]
# ## Importing and Organizing Your Data in Python - Part I

# %% [markdown]
# *Suggested Answers follow (usually there are multiple ways to solve a problem in Python).*

# %% [markdown]
# a. Create a series object of 10 randomly generated integer values.

# %%
import numpy

# %%
a = numpy.random.random(10)
print(a)
# Out:
# [0.09948758 0.80712539 0.34094619 0.005858   0.48411221 0.92446934
#  0.36646158 0.03378128 0.53638132 0.71694371]

# %% [markdown]
# b. Extract data from IEX for Ford from the 1st of January 2015. The ticker you need is ‘F’.

# %%
import pandas_datareader

# %%
help(pandas_datareader)
# Out:
# Help on package pandas_datareader:
#
# NAME
#     pandas_datareader
#
# PACKAGE CONTENTS
#     _testing
#     _utils
#     _version
#     av (package)
#     bankofcanada
#     base
#     compat (package)
#     conftest
#     data
#     econdb
#     enigma
#     eurostat
#     exceptions
#     famafrench
#     fred
#     iex (package)
#     io (package)
#     moex
#     nasdaq_trader
#     oecd
#     quandl
#     robinhood
#     stooq
#     tests (package)
#     tiingo
#     tsp
#     wb
#     yahoo (package)
#
# FUNCTIONS
#     DataReader(name, data_source=None, start=None, end=None, retry_count=3, pause=0.1, session=None, api_key=None)
#         Imports data from a number of online sources.
#
#         Currently supports Google Finance, St. Louis FED (FRED),
#         and Kenneth French's data library, among others.
#
#         Parameters
#         ----------
#         name : str or list of strs
#             the name of the dataset. Some data sources (IEX, fred) will
# ...

# %%
b = pandas_datareader.dataerader(name = 'iex', data_source = )
