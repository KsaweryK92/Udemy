# %% [markdown]
# ## Calculating the Return of Indices

# %% [markdown]
# Consider three famous American market indices – Dow Jones, S&P 500, and the Nasdaq for the period of 1st of January 2000 until today.

# %%
import pandas
import numpy
import matplotlib
import pandas_datareader

# %%
tickers = ['^GSPC', '^IXIC', '^GDAXI']
rec_data = pandas.DataFrame()
for ticker in tickers:
    rec_data[ticker] = pandas_datareader.data.DataReader(ticker, data_source = 'yahoo', start = '2000-1-1')['Adj Close']
rec_data.head(5)
# Out:
#                   ^GSPC        ^IXIC       ^GDAXI
# Date
# 2000-01-03  1455.219971  4131.149902  6750.759766
# 2000-01-04  1399.420044  3901.689941  6586.950195
# 2000-01-05  1402.109985  3877.540039  6502.069824
# 2000-01-06  1403.449951  3727.129883  6474.919922
# 2000-01-07  1441.469971  3882.620117  6780.959961

# %% [markdown]
# Normalize the data to 100 and plot the results on a graph.

# %%
(rec_data / rec_data.iloc[0] * 100).plot(figsize = (15,6))
matplotlib.pyplot.show()

# %% [markdown]
# How would you explain the common and the different parts of the behavior of the three indices?

# %% [markdown]
# *****

# %% [markdown]
# Obtain the simple returns of the indices.

# %%
simp_ret = rec_data / rec_data.shift(1) - 1
simp_ret
# Out:
#                ^GSPC     ^IXIC    ^GDAXI
# Date
# 2000-01-03       NaN       NaN       NaN
# 2000-01-04 -0.038345 -0.055544 -0.024265
# 2000-01-05  0.001922 -0.006190 -0.012886
# 2000-01-06  0.000956 -0.038790 -0.004176
# 2000-01-07  0.027090  0.041718  0.047265
# 2000-01-10  0.011190  0.043025  0.021319
# 2000-01-11 -0.013063 -0.031726 -0.004948
# 2000-01-12 -0.004386 -0.018150  0.003129
# 2000-01-13  0.012170  0.027841  0.006245
# 2000-01-14  0.010671  0.027054  0.031231
# 2000-01-18 -0.006832  0.016372 -0.014094
# 2000-01-19  0.000522  0.004958  0.002675
# 2000-01-20 -0.007095  0.009207  0.003049
# 2000-01-21 -0.002912  0.010954 -0.016859
# 2000-01-24 -0.027634 -0.032894 -0.008689
# 2000-01-25  0.006065  0.017414 -0.017650
# 2000-01-26 -0.004213 -0.023396  0.023456
# 2000-01-27 -0.003938 -0.007457  0.022493
# 2000-01-28 -0.027457 -0.037749 -0.008354
# 2000-01-31  0.025218  0.013707 -0.032689
# 2000-02-01  0.010628  0.028330  0.031432
# 2000-02-02 -0.000114  0.005425  0.017232
# 2000-02-03  0.011248  0.033633  0.025420
# 2000-02-04 -0.000421  0.007875  0.012285
# 2000-02-07 -0.000091  0.018291 -0.019919
# 2000-02-08  0.012273  0.024465  0.034752
# 2000-02-09 -0.020815 -0.014514  0.010494
# 2000-02-10  0.003627  0.028050  0.010507
# 2000-02-11 -0.020969 -0.020104 -0.012676
# 2000-02-14  0.002033  0.005255  0.004368
# ...              ...       ...       ...
# 2019-08-27 -0.003203 -0.003411  0.006174
# 2019-08-28  0.006545  0.003824 -0.002472
# 2019-08-29  0.012687  0.014829  0.011782
# 2019-08-30  0.000643 -0.001318  0.008481
# 2019-09-03 -0.006899 -0.011142 -0.002380
# 2019-09-04  0.010842  0.013045  0.009586
# 2019-09-05  0.013010  0.017544  0.008461
# 2019-09-06  0.000911 -0.001695  0.005356
# 2019-09-09 -0.000094 -0.001929  0.002819
# 2019-09-10  0.000322 -0.000406  0.003485
# 2019-09-11  0.007230  0.010579  0.007365
# 2019-09-12  0.002879  0.003034  0.004141
# 2019-09-13 -0.000724 -0.002167  0.004696
# 2019-09-16 -0.003136 -0.002834 -0.007075
# 2019-09-17  0.002582  0.003984 -0.000622
# 2019-09-18  0.000343 -0.001054  0.001375
# 2019-09-19  0.000020  0.000671  0.005495
# 2019-09-20 -0.004896 -0.007969  0.000828
# 2019-09-23 -0.000097 -0.000642 -0.010080
# 2019-09-24 -0.008416 -0.014648 -0.002850
# 2019-09-25  0.006159  0.010477 -0.005929
# 2019-09-26 -0.002429 -0.005784  0.004443
# 2019-09-27 -0.005316 -0.011335  0.007519
# 2019-09-30  0.005048  0.007520  0.003807
# 2019-10-01 -0.012258 -0.011333 -0.013216
# 2019-10-02 -0.017903 -0.015607 -0.027608
# 2019-10-03  0.007972  0.011176       NaN
# 2019-10-04  0.014217  0.014000       NaN
# 2019-10-07 -0.004478 -0.003280  0.007044
# 2019-10-08 -0.009776 -0.010032 -0.010517
#
# [4973 rows x 3 columns]

# %% [markdown]
# Estimate the average annual return of each index.

# %%
simp_ret.mean() * 250
# Out:
# ^GSPC     0.052699
# ^IXIC     0.063213
# ^GDAXI    0.041961
# dtype: float64
