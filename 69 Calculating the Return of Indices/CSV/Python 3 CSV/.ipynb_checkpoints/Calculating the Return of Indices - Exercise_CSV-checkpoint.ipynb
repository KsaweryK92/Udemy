# %% [markdown]
# ## Calculating the Return of Indices

# %% [markdown]
# Consider three famous American market indices – Dow Jones, S&P 500, and the Nasdaq for the period of 1st of January 2000 until today.

# %%
import pandas
new_data = pandas.read_csv(r'/home/ksawery/PycharmProjects/Udemy/Python for Finance - Notebook Files/69 Calculating the Return of Indices/CSV/Python 3 CSV/Indices_Data_01.csv')
new_data = new_data[new_data.Date >= '2000-01-01'].set_index('Date')
print(new_data.info())
print(new_data.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4333 entries, 2000-01-03 to 2017-03-23
# Data columns (total 4 columns):
# ^GSPC     4333 non-null float64
# ^IXIC     4333 non-null float64
# ^GDAXI    4265 non-null float64
# ^FTSE     4255 non-null float64
# dtypes: float64(4)
# memory usage: 169.3+ KB
# None
#                   ^GSPC        ^IXIC       ^GDAXI        ^FTSE
# Date
# 2000-01-03  1455.219971  4131.149902  6750.759766          NaN
# 2000-01-04  1399.420044  3901.689941  6586.950195  6665.899902
# 2000-01-05  1402.109985  3877.540039  6502.069824  6535.899902
# 2000-01-06  1403.449951  3727.129883  6474.919922  6447.200195
# 2000-01-07  1441.469971  3882.620117  6780.959961  6504.799805

# %% [markdown]
# Normalize the data to 100 and plot the results on a graph.

# %%
import matplotlib.pyplot as plt
((new_data / new_data.iloc[0]) * 100).plot(figsize = (15, 5))
plt.show()

# %% [markdown]
# How would you explain the common and the different parts of the behavior of the three indices?

# %% [markdown]
# Obtain the simple returns of the indices.

# %%
((new_data / new_data.shift(1)) - 1).mean()
# Out:
# ^GSPC     0.000187
# ^IXIC     0.000212
# ^GDAXI    0.000191
# ^FTSE     0.000062
# dtype: float64

# %% [markdown]
# Estimate the average annual return of each index.

# %%
zwroty = pandas.Series()
zwroty = ((new_data / new_data.shift(1)) - 1).mean() * 250
wagi = pandas.Series([0.25, 0.25, 0.25, 0.25])
print(zwroty)
# Out:
# ^GSPC     0.046700
# ^IXIC     0.052936
# ^GDAXI    0.047819
# ^FTSE     0.015471
# dtype: float64

# %%
import numpy
numpy.dot(zwroty, wagi) * 100
# Out:
# 4.07313739280054
